# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
name = ['a','b','c']
data = pd.read_csv('QSO.sed',sep='\t',comment='#',names=name)
data = data[:-1]
x = data['a'].to_numpy().astype(float)
y = data['b'].to_numpy()
data
# Out:
#                  a         b      c
# 0      9.61225e-04  0.053343  nufnu
# 1      1.00653e-03  0.061247    NaN
# 2      1.05396e-03  0.068720    NaN
# 3      1.10363e-03  0.077105    NaN
# 4      1.15565e-03  0.088528    NaN
# ...            ...       ...    ...
# 6773   3.41257e+05  0.000709    NaN
# 6774   7.35262e+05  0.000329    NaN
# 6775   1.58417e+06  0.000153    NaN
# 6776   3.41321e+06  0.000071    NaN
# 6777   7.35400e+06  0.000033    NaN
#
# [6778 rows x 3 columns]

# %%
hnu =  9.61225e-04
h = 4.15e-15
nu = hnu / h 
print(r'{:.2e}'.format(nu))
# Out:
# 2.32e+11

# %%
plt.plot(x,y*h)
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e-3,1e5)
plt.ylim(1e-17,3e-14)
# Out:
# (1e-17, 3e-14)

# %%
plt.plot(x,y)
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e-3,1e5)
# Out:
# (0.001, 100000.0)
