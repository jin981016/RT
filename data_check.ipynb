# %%
from DATA_CHECK import *


path_d = '/home/jin/data_CIV'


style ='radi'


# ----- Common -----
V_out  = 500 
V_emit = 1000
V_rand = 11.8
# ----- Common -----

# ----- Data -----
# atom_num, atom_index = 32 , 15
# path_Data = Data_path(path_d,style, atom_num, atom_index , V_out, V_emit, V_rand)
# print(path_Data)
# ----- Data -----

#------ SB --------
Geometry = 3  # 1 = Test , 2 = Nebula , 3 = QSO, 4 = AGN_con, 5 = Flat
atom = 'CIV'
path_s = '/home/jin/RT/RT_scat'
data_file = 'CLOUDY'
Lumin = 44.0 
idx = 2
metals = 1.0
Column_density_order = 22.0




path_SB =RT_CLOUDY_path(path_s,data_file,V_out, V_emit, V_rand, Geometry, atom, Lumin,idx,metals,Column_density_order)
print(path_SB)
#------ SB --------
# Out:
# /home/jin/RT/RT_scat/WOCIVL440M1NH220/N_atom300E+10_Vexp500E+02_Vemit100E+03_tauD000E+00_Vran118E+01

# %%
V_out  = 0
V_emit = 3000
V_rand = 0
Geometry = 3  # 1 = Test , 2 = Nebula , 3 = QSO, 4 = AGN_con, 5 = Flat
atom = 'CIV'
path_s = '/home/jin/RT/RT_scat/test_QSO'
data_file = 'SB'
path_SB = RT_CLOUDY_path(path_s,data_file,V_out, V_emit, V_rand, Geometry, atom, Lumin,idx,metals,Column_density_order)

lam, spec_tot, spec_sc = spec_com(path_SB)
print(f'{np.sum(spec_tot):.2e}')
plt.plot(lam,spec_tot,'b-')

Geometry = 1

path_SB = RT_CLOUDY_path(path_s,data_file,V_out, V_emit, V_rand, Geometry, atom, Lumin,idx,metals,Column_density_order)

lam, spec_tot, spec_sc = spec_com(path_SB)
print(f'{np.sum(spec_tot):.2e}')
plt.plot(lam,spec_tot,'k--')
# Out:
# Lambda, Escape+Scattering Photon Spectrum, Scattering Photon Spectrum
# 9.99e+06
# Lambda, Escape+Scattering Photon Spectrum, Scattering Photon Spectrum
# 1.00e+07

# %%
lam, spec_tot, spec_sc = spec_com(path_SB)
print(f'{np.sum(spec_tot):.2e}')
total_num = np.sum(spec_tot)
total_civ = 3.044789308699308e+42 #erg/s

photon_energy = (total_civ / total_num) #erg/s
# Lc = 6e40
# flux = (total_civ / total_num) * (spec_tot ) # erg/s/A
flux = (spec_tot) # * (total_civ / total_num)
plt.plot(lam,flux)
# Out:
# Lambda, Escape+Scattering Photon Spectrum, Scattering Photon Spectrum
# 1.00e+07

# %%
V_out  = 500 
V_emit = 3000
V_rand = 11.8
path_s = '/home/jin/RT/RT_scat/flat_AGN'
Geometry = 3
style= 'Test'
path_SB = SB_path(path_s,style,V_out, V_emit, V_rand, Geometry, atom, Lumin,idx,metals,Column_density_order)

lam, spec_tot, spec_sc = spec_com(path_SB)

plt.plot(lam,spec_tot)
print(f'{sum(spec_tot):.2e}')
# radius, radius_kpc, SB_total=  RT_SB(path_SB) 

# plt.plot(radius,SB_total)
# plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       5 Geometry = 3
#       6 style= 'Test'
# ----> 7 path_SB = SB_path(path_s,style,V_out, V_emit, V_rand, Geometry, atom, Lumin,idx,metals,Column_density_order)
#       9 lam, spec_tot, spec_sc = spec_com(path_SB)
#      11 plt.plot(lam,spec_tot)
#
# NameError: name 'SB_path' is not defined
